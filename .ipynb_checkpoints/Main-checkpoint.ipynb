# %% [markdown]
# # Does my country represent my personality?
#
# ## Introduction
#
# People fill out online personality tests with the hope of gaining some insight into themselves. Can we use this type of data to answer some interesting questions about psychometric tests regarding nationality, and personality types?
#
# ## Questions
#
# 1. Do different countries have different scores of the big 5 personality traits? Which are the most of each personality?
# 2. Does being any other type of personality mean that you are likely to be another personality too?
# 3. Is the time taken to complete a personality trait? (ie: did people who scored higher in being conscientuss take longer to complete the test?)
#
#
#
# ## Data
#
# The data used in this notebook is provided by kaggle (https://www.kaggle.com/tunguz/big-five-personality-test). The dataset includes information about how each participant answered each of the 50 questions. Each question contains a statement, and the participants answer with a 1 to 5, whether they do not agree with the statement or strongly agree with it. There is also data about how long each participant took to answer each question, measured in milliseconds. The dateload column represents the datetime stamp for when the page was loaded, screenw and screenh represent the screen resolution. Introelapse, testelapse, and endelapse are the time in seconds spent in the intro page, time it took to complete the test, and the time spent on the results page. Other information included is location of the country from where the test was completed, number of records from the same IP address, and the lattitude and longitude with high margin of error.
#
# Lets take a quick look into the data:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from helper_functions import *
alldata=pd.read_csv('data-final.csv', sep='\t')
alldata.head()
# Out:
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
#
#               dateload  screenw  screenh  introelapse  testelapse  endelapse  \
# 0  2016-03-03 02:01:01    768.0   1024.0          9.0       234.0          6
# 1  2016-03-03 02:01:20   1360.0    768.0         12.0       179.0         11
# 2  2016-03-03 02:01:56   1366.0    768.0          3.0       186.0          7
# 3  2016-03-03 02:02:02   1920.0   1200.0        186.0       219.0          7
# 4  2016-03-03 02:02:57   1366.0    768.0          8.0       315.0         17
#
#    IPC  country  lat_appx_lots_of_err  long_appx_lots_of_err
# ...

# %%
alldata_no_na = alldata.dropna()
print("Total number of rows dropped is {} ".format(alldata.shape[0]-alldata_no_na.shape[0]))
print("Total Nan rows dropped are {} % of the data".format(
    (alldata.shape[0]-alldata_no_na.shape[0])/alldata.shape[0]*100))
alldata.isna().sum().sort_values(ascending=False).head(25)
# Out:
# Total number of rows dropped is 3291
# Total Nan rows dropped are 0.3241275591156075 % of the data
# introelapse    2066
# screenh        2066
# screenw        2066
# EXT5_E         1783
# CSN10          1783
# AGR9           1783
# AGR10          1783
# CSN1           1783
# CSN2           1783
# CSN3           1783
# CSN4           1783
# CSN5           1783
# CSN6           1783
# CSN7           1783
# CSN8           1783
# CSN9           1783
# OPN2           1783
# OPN1           1783
# AGR7           1783
# OPN3           1783
# OPN4           1783
# OPN5           1783
# OPN6           1783
# OPN7           1783
# OPN8           1783
# dtype: int64

# %% [markdown]
# As we can observe from the table above, removing all rows containing Nans removes roughly 0.3% of the data, which should not affect the rest of the analysis. 1783 of dropped rows miss psychometric data

# %% [markdown]
# ## Computing the big 5 personalities
#
# In order to compute the 5 personality types, we rely on the following document https://openpsychometrics.org/printable/big-five-personality-test.pdf, which describes how the scores are computed.

# %%
# create a questions by code list
import pandas as pd
import numpy as np
qcodes=pd.read_csv('qcodes.csv', header=None, sep=',')
qcodes.head(10)
# Out:
#       0                                                1                2
# 0  code                                         question  question_number
# 1  EXT1                      I am the life of the party.                1
# 2  EXT2                              I don't talk a lot.                6
# 3  EXT3                I feel comfortable around people.               11
# 4  EXT4                        I keep in the background.               16
# 5  EXT5                           I start conversations.               21
# 6  EXT6                            I have little to say.               26
# 7  EXT7  I talk to a lot of different people at parties.               31
# 8  EXT8        I don't like to draw attention to myself.               36
# 9  EXT9      I don't mind being the center of attention.               41

# %% [markdown]
# Using the information above, I use the compute_psychometrics to populate 5 new columns, with the label of each personality test scored.

# %%
alldata_no_na=compute_psychometrics(alldata_no_na)
alldata_no_na[['E','A', 'C','N','O']].head(5)
# Out:
# C:\Users\Juggernaut\OneDrive\Documents\udacity\Personality test\helper_functions.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   + dataframe['EXT9'] - dataframe['EXT10'])
# C:\Users\Juggernaut\OneDrive\Documents\udacity\Personality test\helper_functions.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   +dataframe['AGR9'] + dataframe['AGR10'] )
# C:\Users\Juggernaut\OneDrive\Documents\udacity\Personality test\helper_functions.py:72: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## Filter Countries
#
# While trying to answer question 1, I noticed that there are countries with as little as one entry, and that should not be representing an entire country. Thus I removed all the countries with less than 100 entries from further analysis in order to answer question 1.

# %%
filtered_countries = filter_countries(alldata_no_na, minvalues=100)
print("Number of rows removed: {}".format(alldata_no_na.shape[0]-filtered_countries.shape[0]))
print("Percent of rows removed: {} %".format(100*(alldata_no_na.shape[0]-
                                              filtered_countries.shape[0])/alldata_no_na.shape[0]))
# Out:
# Number of rows removed: 16158
# Percent of rows removed: 1.5965614347117236 %

# %% [markdown]
# Considering that we are retaining more than 95 % of the data, our following analysis should be sound.
#
# ## Country Averages
#
# In order to compare countries, I decided to obtain the average 5 personality traits for each country, and compare if the countries actually have different "personalities".

# %%
countries = country_averages(filtered_countries)
countries.head(15)
# Out:
# WARNING:root:SAH not found in ISO3
# WARNING:root:PSX not found in ISO3
# WARNING:root:CYN not found in ISO3
# WARNING:root:SOL not found in ISO3
# WARNING:root:KOS not found in ISO3
# WARNING:root:SDS not found in ISO3
#                         country country_code  \
# 0                          Fiji           FJ
# 1   United Republic of Tanzania           TZ
# 2                Western Sahara    not found
# 3                     Palestine    not found
# 4               Northern Cyprus    not found
# 5                    Somaliland    not found
# 6                        Kosovo    not found
# 7                   South Sudan    not found
# 8                        Canada           CA
# 9      United States of America           US
# 10                   Kazakhstan           KZ
# 11                   Uzbekistan           UZ
# 12             Papua New Guinea           PG
# 13                    Indonesia           ID
# 14                    Argentina           AR
#
# ...

# %% [markdown]
# #### Important Note: Countries with values of 0 represent the countries with not enough entries.
#
# ## Plotting the World!
#
# What better way to see how countries compare, than plot the whole world! Here I have used the function plot_map, to plot a global view of the country averages.

# %%
# feel free to change the value for the column
plot_map(countries, 'E')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1043">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ffc82e23-c997-4440-8ec1-d067ac515858" data-root-id="1004"></div>
# Top 10 countries in the psychometric
#          country          E
# 168     Ethiopia  21.342960
# 26        Norway  21.002333
# 134  Netherlands  20.968670
# 92          Oman  20.964912
# 146      Denmark  20.929053
# 82       Lebanon  20.846707
# 175   Montenegro  20.626761
# 10    Kazakhstan  20.566540
# 140  New Zealand  20.426525
# 164       Cyprus  20.409677

# %% [markdown]
# We can see that different countries actually average differently on each of the psychometrics! Seeing this geographical map, actually contradicts what I would expect (Brazil being more extroverted than Russia? Who could have thought that).

# %% [markdown]
# ## Personality Correlations
#
# Does being one personality mean that you are likely to be another one? In order to answer this question, we can do a Pearson's Correlation analysis between the scores of the 5 psychometric scores, and observe the results.

# %%
import seaborn as sns
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
plt.figure(figsize=(12, 6))
sns.heatmap(filtered_countries[['E','A','N','C','O']].corr(),annot=True, cmap= cmap, vmin = 0, vmax= 0.5)

# %% [markdown]
# We need not comment on the diagonal of the plot, as that represents correlation of a column with itself, but although there appears to be mild correlations between some of the columns!
# - A high score of Extroverted is mildly correlated with a high score of Agreeable, and Neuroticism.
# - Agreeable has a weak correlation with Conscientusness, and a mild correlatio nwith Extroverted.
# - Neuroticism has mild correlation with Extrverted and Counscientusness.
# - Conscientousness is mildly correlated with Neuroticism, and weakly correlated with Agreeable.
#
# The only trait with no correlations to any other trait is Open to Experience, which appears to be independent of the other psychometric scores, thus you never know who would be down to get weird, worth asking everyone as you might never know! (Friendly advice; do not ask your boss :))
#
# ## Testing Times
#
# Are the psychometric scores correlated with test times? This is worth exploring as one personality might take longer to take the test, while others might just breeze by. <br>
# A correlation analysis (again!) will show whether a person who scored high in a specific personality, might take longer to take the test. Before running the correlation analysis, it is worth removing outliers for times (for those who clicked like robots without reading, and for those who fell asleep during the test or left for lunch and came back after a week to it again). The function remove_outliers will help with this task.

# %%
removed_outliers = remove_outliers(filtered_countries,
                                   column_names=['introelapse','testelapse','endelapse'])
plt.figure(figsize=(12, 6))
sns.heatmap(removed_outliers[['E','A','N','C','O', 'introelapse', 'testelapse','endelapse']].corr(),
            annot=True, cmap = cmap, fmt='.2f');
# Out:
# removed 13 % of the rows

# %% [markdown]
# It is clear that the time it took to complete the test is not an indication of a certain personality trait, whether someone took a long time in the intro, to complete the survery or at the results page is not an indication of any personality trait.
#
# ## Conclusions
#
# - Certain countries appeared to actually score higher than others in psychometric scores! This might indicate that culture of a region affects the general psyche of its residents.
# - It can be assumed that scoring high on a certain personality gives a considerable probability to scoring high on another personality.
# - Testing times do not affect the scoring on any of the personality scores.
#
# #### Drawbacks of the data
#
# The data helped provide some insights that I did not think would have been true if otherwise, however I wish the data included some more demographic information such as:
# - Age
# - Gender
# - Education
# - Income
# - Occupation
# - Marital Status
# - number of children
#
# I belive that the demographic information could help tease the data better, and maybe provide more insight.
#
# ###### As a final note, thank you for reading my work!
